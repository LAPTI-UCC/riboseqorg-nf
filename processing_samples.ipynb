# %%
import pandas as pd 
from Bio import Entrez 
from info_from_pmid import get_info_from_medline

# %%
from config import ncbi_email 
Entrez.email = ncbi_email

# %%
argeos_path = 'data/argeos_Ribosome_profiling_Human.tsv'

argeos = pd.read_csv(argeos_path, sep="\t")
print(argeos.SRA)

for i in range(len(list(argeos.Accession))):
    if argeos.at[i, "SRA"] != "None":
        argeos.at[i, "SRA"] = argeos.at[i, "SRA"].split("=")[1]
# Out:
# 0      https://www.ncbi.nlm.nih.gov/sra?term=SRP233220
# 1                                                 None
# 2      https://www.ncbi.nlm.nih.gov/sra?term=SRP114759
# 3      https://www.ncbi.nlm.nih.gov/sra?term=SRP192590
# 4      https://www.ncbi.nlm.nih.gov/sra?term=SRP047065
#                             ...
# 391    https://www.ncbi.nlm.nih.gov/sra?term=SRP119397
# 392    https://www.ncbi.nlm.nih.gov/sra?term=SRP133177
# 393                                               None
# 394                                               None
# 395                                               None
# Name: SRA, Length: 396, dtype: object

# %%
geo_ribosome_profiling_path = 'data/geo_ribosomeprofiling.tsv'

geo_ribosome_profiling = pd.read_csv(geo_ribosome_profiling_path, sep='\t')
print(geo_ribosome_profiling.SRA)
# Out:
# 0      SRP346338
# 1      SRP293929
# 2      SRP317900
# 3      SRP329509
# 4      SRP278667
#          ...
# 126    SRP009321
# 127    SRP007567
# 128    SRP002605
# 129    SRP003554
# 130    SRP000637
# Name: SRA, Length: 131, dtype: object

# %%
all_accessions = []
for i in list(geo_ribosome_profiling.Accession):
    if i not in all_accessions:
        all_accessions.append(i)

for i in list(argeos.Accession):
    if i not in all_accessions:
        all_accessions.append(i)

print(geo_ribosome_profiling.index)
print(argeos.index)
print(len(all_accessions))
# Out:
# RangeIndex(start=0, stop=131, step=1)
# RangeIndex(start=0, stop=396, step=1)
# 479

# %%
on = ["Accession", "Title", "Organism", "Samples", "SRA", "Release_Date", "Organism"]
superset = pd.merge(geo_ribosome_profiling, argeos, how='outer', on=on)

# %%
columns = ['Type']
index = [i for i, row in superset.iterrows()]
type_df = pd.DataFrame(index=index, columns=columns)
for i, row in superset.iterrows():
    if str(row['Type_x']) != 'nan':
        type_df.at[i, 'Type'] = str(row['Type_x'])
    else:
        type_df.at[i, 'Type'] = str(row['Type_y'])

# %%
superset = pd.concat([superset, type_df], axis=1)

# %%
for col in superset.columns:
    if 'Type_' in col:
        del superset[col]

# %%
import validators 


columns = ['GSE', 'GSE_Supplementary', 'BioProject']
index = [i for i, row in superset.iterrows()]
link_df = pd.DataFrame(index=index, columns=columns)

gse_supp_base = 'ftp://ftp.ncbi.nlm.nih.gov/geo/series/'
gse_base = "https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc="

for i, row in superset.iterrows():
    if str(row['Supplementary Links']) != 'nan':
        links = superset.at[i, 'Supplementary Links'].split(';')
        for link in links: 
            if "GSE" in link:
                gse_accession = link.split('/')[-2]

                link_df.at[i, 'GSE_Supplementary'] = link
                link_df.at[i, 'GSE'] = gse_base + gse_accession
            elif "PRJ" in link:
                link_df.at[i, "BioProject"] = link


    else:
        if "GSE" in row['Link']:
            gse_accession = row['Link'].split('=')[-1]
            link_df.at[i, 'GSE'] = row['Link']
            link_df.at[i, 'BioProject'] = row['BioProject link (NCBI)']
            if validators.url(gse_supp_base + gse_accession[:5] + "nnn/" + gse_accession + "/suppl"):
                link_df.at[i, 'GSE_Supplementary'] = gse_supp_base + gse_accession[:-3] + "nnn/" + gse_accession + "/suppl"
            else: 
                link_df.at[i,'GSE_Supplementary'] = ""

        else:
            link_df.at[i,'GSE'] = ""
            link_df.at[i,'GSE_Supplementary'] = ""
            link_df.at[i,'BioProject'] = ""


print(link_df.columns)

'''
This is still not working. The constructed supplementary links do not work. 
'''
# Out:
# Index(['GSE', 'GSE_Supplementary', 'BioProject'], dtype='object')
# '\nThis is still not working. The constructed supplementary links do not work. \n'

# %%
superset = pd.concat([superset, link_df], axis=1)

# %%
for col in superset.columns:
    if col in ['Link', 
    'Supplementary Links', 
    'Supplementary Types', 
    'BioProject link (NCBI)', 
    'BioProject link (EBI)', 
    'All References', 
    'Platform', 
    'Type of molecule', 
    'Impact factor 2018', 
    'Summary'
    ]:
        del superset[col]

# %%
index = [i for i, row in superset.iterrows()]

paper_info_df = pd.DataFrame(columns=["PMID", "authors", "abstract", "title", "doi", "date_published", "PMC", "journal"], index=index)
for i, row in superset.iterrows():
    if str(row['PubMed ID']) != "nan":
        if paper_info_df.at[i, 'PMID'] != "nan":
            if len(str(row['PubMed ID'])) > 0:  
                print(str(row['PubMed ID']))    

                info_dict = get_info_from_medline(row['PubMed ID'])
                for item in info_dict:
                    paper_info_df.at[i, item] = info_dict[item]
    else:
        if str(row['doi or pubmed id']) != "nan":
            if "doi" in row['doi or pubmed id']:
                query = row['doi or pubmed id'].split('doi.org/')[-1]

                if len(str(query)) > 0:      
                    print(query)    
                    info_dict = get_info_from_medline(query)
                    for item in info_dict:
                        paper_info_df.at[i, item] = info_dict[item]
        else:
            continue
    print("index: \t", i)
    print(paper_info_df.iloc[i])
    print()
# Out:
# 34899662
# index: 	 0
# PMID                                                       34899662
# authors            Xuejing Fan,  Tianyu Bao,  Huaxi Yi,  Zongcai...
# abstract          To determine whether osmotic pressure affects ...
# title             Ribosome Profiling and RNA Sequencing Reveal G...
# doi                                       10.3389/fmicb.2021.781454
# date_published                                                 2021
# PMC                                                      PMC8656396
# journal                                   Frontiers in microbiology
# Name: 0, dtype: object
#
# 34535544
# index: 	 3
# PMID                                                       34535544
# authors            Srivats Venkataramanan,  Margaret Gadek,  Lor...
# abstract          DDX3 is a DEAD-box RNA helicase that regulates...
# title             DDX3X and DDX3Y are redundant in protein synth...
# doi                                          10.1261/rna.078926.121
# date_published                                             2021 Dec
# PMC                                                      PMC8594478
# journal                                        RNA (New York, N.Y.)
# Name: 3, dtype: object
#
# 34900236
# index: 	 5
# PMID                                                       34900236
# authors            Artyom A Egorov,  Desislava S Makeeva,  Nadez...
# abstract          In eukaryotes, stalled and collided ribosomes ...
# title             Ribo-Seq and RNA-Seq of TMA46 ( DFRP1) and GIR...
# doi                                  10.12688/f1000research.74727.1
# date_published                                                 2021
# PMC                                                      PMC8637242
# journal                                               F1000Research
# Name: 5, dtype: object
#
# 34900236
# index: 	 6
# PMID                                                       34900236
# authors            Artyom A Egorov,  Desislava S Makeeva,  Nadez...
# abstract          In eukaryotes, stalled and collided ribosomes ...
# title             Ribo-Seq and RNA-Seq of TMA46 ( DFRP1) and GIR...
# doi                                  10.12688/f1000research.74727.1
# date_published                                                 2021
# PMC                                                      PMC8637242
# journal                                               F1000Research
# Name: 6, dtype: object
#
# 34615539
# index: 	 7
# PMID                                                       34615539
# authors            Sarah L Gillen,  Chiara Giacomelli,  Kelly Ho...
# abstract          BACKGROUND: Regulation of protein output at th...
# title             Differential regulation of mRNA fate by the hu...
# doi                                      10.1186/s13059-021-02494-w
# date_published                                           2021 Oct 6
# PMC                                                      PMC8496106
# journal                                              Genome biology
# Name: 7, dtype: object
#
# 34093996
# index: 	 8
# PMID                                                       34093996
# authors            Pauline Francois,  Hugo Arbes,  Stephane Dema...
# abstract          Ribosome profiling (RiboSeq) has emerged as a ...
# title             RiboDoc: A Docker-based package for ribosome p...
# doi                                      10.1016/j.csbj.2021.05.014
# date_published                                                 2021
# PMC                                                      PMC8141510
# journal           Computational and structural biotechnology jou...
# Name: 8, dtype: object
#
# 34429433
# index: 	 9
# PMID                                                       34429433
# authors            Puneet Sharma,  Jie Wu,  Benedikt S Nilges,  ...
# abstract          Ribosome profiling measures genome-wide transl...
# title             Humans and other commonly used model organisms...
# doi                                      10.1038/s41467-021-25411-y
# date_published                                          2021 Aug 24
# PMC                                                      PMC8384890
# journal                                       Nature communications
# Name: 9, dtype: object
#
# 34244513
# index: 	 10
# PMID                                                       34244513
# authors            Yiting Lim,  Sonali Arora,  Samantha L Schust...
# abstract          The functional consequences of genetic variant...
# title             Multiplexed functional genomic analysis of 5' ...
# doi                                      10.1038/s41467-021-24445-6
# date_published                                           2021 Jul 9
# PMC                                                      PMC8270899
# journal                                       Nature communications
# Name: 10, dtype: object
#
# 33357414
# index: 	 11
# PMID                                                       33357414
# authors            Matthew L Kraushar,  Ferdinand Krupp,  Dermot...
# abstract          Protein synthesis must be finely tuned in the ...
# title             Protein Synthesis in the Developing Neocortex ...
# doi                                    10.1016/j.molcel.2020.11.037
# date_published                                          2021 Jan 21
# PMC                                                      PMC8163098
# journal                                              Molecular cell
# Name: 11, dtype: object
#
# 33357414
# index: 	 12
# PMID                                                       33357414
# authors            Matthew L Kraushar,  Ferdinand Krupp,  Dermot...
# abstract          Protein synthesis must be finely tuned in the ...
# title             Protein Synthesis in the Developing Neocortex ...
# doi                                    10.1016/j.molcel.2020.11.037
# date_published                                          2021 Jan 21
# PMC                                                      PMC8163098
# journal                                              Molecular cell
# Name: 12, dtype: object
#
# 33472542
# index: 	 13
# PMID                                                       33472542
# authors            Ravi Tharakan,  Ceereena Ubaida-Mohien,  Yula...
# abstract          With advancing age, human muscle loses strengt...
# title             Ribosome profiling analysis of human skeletal ...
# doi                                   10.1080/15476286.2021.1875647
# date_published                                             2021 Nov
# PMC                                                      PMC8583053
# journal                                                 RNA biology
# Name: 13, dtype: object
#
# 33472542
# index: 	 14
# PMID                                                       33472542
# authors            Ravi Tharakan,  Ceereena Ubaida-Mohien,  Yula...
# abstract          With advancing age, human muscle loses strengt...
# title             Ribosome profiling analysis of human skeletal ...
# doi                                   10.1080/15476286.2021.1875647
# date_published                                             2021 Nov
# PMC                                                      PMC8583053
# journal                                                 RNA biology
# Name: 14, dtype: object
#
# 33472542
# index: 	 15
# PMID                                                       33472542
# authors            Ravi Tharakan,  Ceereena Ubaida-Mohien,  Yula...
# abstract          With advancing age, human muscle loses strengt...
# title             Ribosome profiling analysis of human skeletal ...
# doi                                   10.1080/15476286.2021.1875647
# date_published                                             2021 Nov
# PMC                                                      PMC8583053
# journal                                                 RNA biology
# Name: 15, dtype: object
#
# 34759048
# index: 	 16
# PMID                                                       34759048
# authors            Jungwoo Wren Kim,  Xiling Yin,  Ian Martin,  ...
# abstract          The G2019S mutation in leucine-rich repeat kin...
# title             Dysregulated mRNA Translation in the G2019S LR...
# doi                                     10.1523/ENEURO.0310-21.2021
# date_published                                         2021 Nov-Dec
# PMC                                                      PMC8638676
# journal                                                      eNeuro
# Name: 16, dtype: object
#
# 34554924
# index: 	 17
# PMID                                                       34554924
# authors            Sofia Thomaidou,  Roderick C Slieker,  Arno R...
# abstract          Type 1 diabetes (T1D) is an autoimmune disease...
# title             Long RNA Sequencing and Ribosome Profiling of ...
# doi                                               10.2337/db20-1122
# date_published                                             2021 Oct
# PMC                                                            None
# journal                                                    Diabetes
# Name: 17, dtype: object
#
# 24903108
# index: 	 18
# PMID                                                       24903108
# authors            Yan Han,  Xiangwei Gao,  Botao Liu,  Ji Wan, ...
# abstract          The journey of a newly synthesized polypeptide...
# title             Ribosome profiling reveals sequence-independen...
# doi                                              10.1038/cr.2014.74
# date_published                                             2014 Jul
# PMC                                                      PMC4085768
# journal                                               Cell research
# Name: 18, dtype: object
#
# 33054857
# index: 	 20
# PMID                                                       33054857
# authors            Annie Hien,  Gemma Molinaro,  Botao Liu,  Kim...
# abstract          BACKGROUND: Mutations in TSC2 are the most com...
# title             Ribosome profiling in mouse hippocampus: plast...
# doi                                      10.1186/s13229-020-00384-9
# date_published                                          2020 Oct 14
# PMC                                                      PMC7556950
# journal                                            Molecular autism
# Name: 20, dtype: object
#
# 33054857
# index: 	 21
# PMID                                                       33054857
# authors            Annie Hien,  Gemma Molinaro,  Botao Liu,  Kim...
# abstract          BACKGROUND: Mutations in TSC2 are the most com...
# title             Ribosome profiling in mouse hippocampus: plast...
# doi                                      10.1186/s13229-020-00384-9
# date_published                                          2020 Oct 14
# PMC                                                      PMC7556950
# journal                                            Molecular autism
# Name: 21, dtype: object
#
# 33905506
# index: 	 22
# PMID                                                       33905506
# authors            Lorenzo Calviello,  Srivats Venkataramanan,  ...
# abstract          DDX3 is an RNA chaperone of the DEAD-box famil...
# title             DDX3 depletion represses translation of mRNAs ...
# doi                                             10.1093/nar/gkab287
# date_published                                          2021 May 21
# PMC                                                      PMC8136831
# journal                                      Nucleic acids research
# Name: 22, dtype: object
#
# 32821821
# index: 	 23
# PMID                                                       32821821
# authors            Ke Zou,  Silvia Rouskin,  Kevin Dervishi,  Ma...
# abstract          Caloric restriction (CR) is known to extend li...
# title             Life span extension by glucose restriction is ...
# doi                                          10.1126/sciadv.aba1306
# date_published                                             2020 Aug
# PMC                                                      PMC7406366
# journal                                            Science advances
# Name: 23, dtype: object
#
# 32807779
# index: 	 24
# PMID                                                       32807779
# authors            Evangelos D Karousis,  Lukas-Adrian Gurzeler,...
# abstract          Nonsense-mediated mRNA decay (NMD) is a transl...
# title             Human NMD ensues independently of stable ribos...
# doi                                      10.1038/s41467-020-17974-z
# date_published                                          2020 Aug 17
# PMC                                                      PMC7431590
# journal                                       Nature communications
# Name: 24, dtype: object
#
# 32516567
# index: 	 25
# PMID                                                       32516567
# authors            Elise Y Cai,  Megan N Kufeld,  Samantha Schus...
# abstract          Human skin tolerates a surprisingly high burde...
# title             Selective Translation of Cell Fate Regulators ...
# doi                                      10.1016/j.stem.2020.05.007
# date_published                                           2020 Aug 6
# PMC                                                      PMC7993921
# journal                                              Cell stem cell
# Name: 25, dtype: object
#
# 32576685
# index: 	 26
# PMID                                                       32576685
# authors            Aleksandra S Anisimova,  Mark B Meerson,  Max...
# abstract          Protein synthesis represents a major metabolic...
# title             Multifaceted deregulation of gene expression a...
# doi                                         10.1073/pnas.2001788117
# date_published                                           2020 Jul 7
# PMC                                                      PMC7354943
# journal           Proceedings of the National Academy of Science...
# Name: 26, dtype: object
#
# 32589965
# index: 	 27
# PMID                                                       32589965
# authors            Yingying Lin,  Fajin Li,  Linlu Huang,  Chris...
# abstract          eIF3, a multi-subunit complex with numerous fu...
# title             eIF3 Associates with 80S Ribosomes to Promote ...
# doi                                    10.1016/j.molcel.2020.06.003
# date_published                                          2020 Aug 20
# PMC                                                            None
# journal                                              Molecular cell
# Name: 27, dtype: object
#
# 32302532
# index: 	 30
# PMID                                                       32302532
# authors            Alexander Jais,  Lars Paeger,  Tamara Sotelo-...
# abstract          Calorie-rich diets induce hyperphagia and prom...
# title             PNOC(ARC) Neurons Promote Hyperphagia and Obes...
# doi                                    10.1016/j.neuron.2020.03.022
# date_published                                          2020 Jun 17
# PMC                                                      PMC7303947
# journal                                                      Neuron
# Name: 30, dtype: object
#
# 32385251
# index: 	 31
# PMID                                                       32385251
# authors            Woori Kim,  Soonkyu Hwang,  Namil Lee,  Yongj...
# abstract          Streptomyces are efficient producers of variou...
# title             Transcriptome and translatome profiles of Stre...
# doi                                       10.1038/s41597-020-0476-9
# date_published                                           2020 May 8
# PMC                                                      PMC7210306
# journal                                             Scientific data
# Name: 31, dtype: object
#
# 32040547
# index: 	 32
# PMID                                                       32040547
# authors            Katharina Haneke,  Johanna Schott,  Doris Lin...
# abstract          Cell proliferation exerts a high demand on pro...
# title             CDK1 couples proliferation with protein synthe...
# doi                                           10.1083/jcb.201906147
# date_published                                           2020 Mar 2
# PMC                                                      PMC7054999
# journal                                 The Journal of cell biology
# Name: 32, dtype: object
#
# 31835033
# index: 	 33
# PMID                                                       31835033
# authors            Peng Dai,  Xin Wang,  Lan-Tao Gou,  Zhi-Tong ...
# abstract          Spermiogenesis is a highly orchestrated develo...
# title             A Translation-Activating Function of MIWI/piRN...
# doi                                      10.1016/j.cell.2019.11.022
# date_published                                          2019 Dec 12
# PMC                                                      PMC8139323
# journal                                                        Cell
# Name: 33, dtype: object
#
# 31911279
# index: 	 34
# PMID                                                       31911279
# authors            Christos Vaklavas,  Scott W Blume,  William E...
# abstract          Gene expression is extensively and dynamically...
# title             Hallmarks and Determinants of Oncogenic Transl...
# doi                                    10.1016/j.tranon.2019.12.002
# date_published                                             2020 Feb
# PMC                                                      PMC6948383
# journal                                      Translational oncology
# Name: 34, dtype: object
#
# 31975687
# index: 	 35
# PMID                                                       31975687
# authors            Chih-Yung S Lee,  Andrea Putnam,  Tu Lu,  Shu...
# abstract          RNA granules are protein/RNA condensates. How ...
# title             Recruitment of mRNAs to P granules by condensa...
# doi                                             10.7554/eLife.52896
# date_published                                          2020 Jan 24
# PMC                                                      PMC7007223
# journal                                                       eLife
# Name: 35, dtype: object
#
# 32686713
# index: 	 36
# PMID                                                       32686713
# authors            Nicolas Bonhoure,  Viviane Praz,  Robyn D Moi...
# abstract          Maf1(-/-) mice are lean, obesity-resistant and...
# title             MAF1 is a chronic repressor of RNA polymerase ...
# doi                                      10.1038/s41598-020-68665-0
# date_published                                          2020 Jul 20
# PMC                                                      PMC7371695
# journal                                          Scientific reports
# Name: 36, dtype: object
#
# 31601799
# index: 	 37
# PMID                                                       31601799
# authors            Daniel A Kuppers,  Sonali Arora,  Yiting Lim,...
# abstract          Many of the regulatory features governing eryt...
# title             N(6)-methyladenosine mRNA marking promotes sel...
# doi                                      10.1038/s41467-019-12518-6
# date_published                                          2019 Oct 10
# PMC                                                      PMC6787028
# journal                                       Nature communications
# Name: 37, dtype: object
#
# 31416668
# index: 	 38
# PMID                                                       31416668
# authors            Dylan Kwart,  Andrew Gregg,  Claudia Scheckel...
# abstract          Familial Alzheimer's disease (fAD) results fro...
# title             A Large Panel of Isogenic APP and PSEN1 Mutant...
# doi                                    10.1016/j.neuron.2019.07.010
# date_published                                          2019 Oct 23
# PMC                                                            None
# journal                                                      Neuron
# Name: 38, dtype: object
#
# 31350336
# index: 	 39
# PMID                                                       31350336
# authors            Wenchao Zhao,  Simon Bohleber,  Henrik Schmid...
# abstract          Recoding of UGA codons as selenocysteine (Sec)...
# title             Ribosome profiling of selenoproteins in vivo r...
# doi                                        10.1074/jbc.RA119.009369
# date_published                                          2019 Sep 27
# PMC                                                      PMC6768643
# journal                         The Journal of biological chemistry
# Name: 39, dtype: object
#
# 31340047
# index: 	 40
# PMID                                                       31340047
# authors            Chung-Te Chang,  Sowndarya Muthukumar,  Ramon...
# abstract          XRN1 is the major cytoplasmic exoribonuclease ...
# title             A low-complexity region in human XRN1 directly...
# doi                                              10.1093/nar/gkz633
# date_published                                          2019 Sep 26
# PMC                                                      PMC6753473
# journal                                      Nucleic acids research
# Name: 40, dtype: object
#
# 31292544
# index: 	 41
# PMID                                                       31292544
# authors            Ryan J Ries,  Sara Zaccara,  Pierre Klein,  A...
# abstract          N(6)-methyladenosine (m(6)A) is the most preva...
# title             m(6)A enhances the phase separation potential ...
# doi                                       10.1038/s41586-019-1374-1
# date_published                                             2019 Jul
# PMC                                                      PMC6662915
# journal                                                      Nature
# Name: 41, dtype: object
#
# 32020195
# index: 	 42
# PMID                                                       32020195
# authors            Edward W J Wallace,  Corinne Maufrais,  Jade ...
# abstract          Eukaryotic protein synthesis generally initiat...
# title             Quantitative global studies reveal differentia...
# doi                                             10.1093/nar/gkaa060
# date_published                                          2020 Mar 18
# PMC                                                      PMC7049704
# journal                                      Nucleic acids research
# Name: 42, dtype: object
#
# 31281537
# index: 	 44
# PMID                                                       31281537
# authors            Qin Zou,  Zhengtao Xiao,  Rongyao Huang,  Xin...
# abstract          Despite the critical position of translation i...
# title             Survey of the translation shifts in hepatocell...
# doi                                              10.7150/thno.35033
# date_published                                                 2019
# PMC                                                      PMC6592166
# journal                                                Theranostics
# Name: 44, dtype: object
#
# 30590705
# index: 	 45
# PMID                                                       30590705
# authors            Botao Liu,  Gemma Molinaro,  Huan Shu,  Emily...
# abstract          Dysregulated protein synthesis is a major unde...
# title             Optimization of ribosome profiling using low-i...
# doi                                             10.1093/nar/gky1292
# date_published                                          2019 Mar 18
# PMC                                                      PMC6411937
# journal                                      Nucleic acids research
# Name: 45, dtype: object
#
# 30875926
# index: 	 46
# PMID                                                       30875926
# authors            Gesche K Gerresheim,  Jochen Bathke,  Audrey ...
# abstract          BACKGROUND: Hepatitis C virus (HCV) infects hu...
# title             Cellular Gene Expression during Hepatitis C Vi...
# doi                                            10.3390/ijms20061321
# date_published                                          2019 Mar 15
# PMC                                                      PMC6470931
# journal                 International journal of molecular sciences
# Name: 46, dtype: object
#
# 30867593
# index: 	 47
# PMID                                                       30867593
# authors            Huilin Huang,  Hengyou Weng,  Keren Zhou,  To...
# abstract          DNA and histone modifications have notable eff...
# title             Histone H3 trimethylation at lysine 36 guides ...
# doi                                       10.1038/s41586-019-1016-7
# date_published                                             2019 Mar
# PMC                                                      PMC6438714
# journal                                                      Nature
# Name: 47, dtype: object
#
# 30837344
# index: 	 49
# PMID                                                       30837344
# authors            Jeremy Weaver,  Fuad Mohammad,  Allen R Buski...
# abstract          Small proteins consisting of 50 or fewer amino...
# title             Identifying Small Proteins by Ribosome Profili...
# doi                                           10.1128/mBio.02819-18
# date_published                                           2019 Mar 5
# PMC                                                      PMC6401488
# journal                                                        mBio
# Name: 49, dtype: object
#
# 30413617
# index: 	 51
# PMID                                                       30413617
# authors            Zhao Su,  Yin Tang,  Laura E Ritchey,  David ...
# abstract          The heat shock response is crucial for organis...
# title             Genome-wide RNA structurome reprogramming by a...
# doi                                         10.1073/pnas.1807988115
# date_published                                          2018 Nov 27
# PMC                                                      PMC6275526
# journal           Proceedings of the National Academy of Science...
# Name: 51, dtype: object
#
# 30355487
# index: 	 52
# PMID                                                       30355487
# authors            Massimiliano Clamer,  Toma Tebaldi,  Fabio La...
# abstract          Ribosome profiling, or Ribo-seq, is based on l...
# title                      Active Ribosome Profiling with RiboLace.
# doi                                    10.1016/j.celrep.2018.09.084
# date_published                                          2018 Oct 23
# PMC                                                            None
# journal                                                Cell reports
# Name: 52, dtype: object
#
# 30380414
# index: 	 53
# PMID                                                       30380414
# authors            Leah L Zagore,  Thomas J Sweet,  Molly M Hann...
# abstract          The RNA binding protein DAZL is essential for ...
# title             DAZL Regulates Germ Cell Survival through a Ne...
# doi                                    10.1016/j.celrep.2018.10.012
# date_published                                          2018 Oct 30
# PMC                                                      PMC6878787
# journal                                                Cell reports
# Name: 53, dtype: object
#
# 29997263
# index: 	 54
# PMID                                                       29997263
# authors            Gavin Hanson,  Najwa Alhusaini,  Nathan Morri...
# abstract          Messenger RNA (mRNA) degradation plays a criti...
# title             Translation elongation and mRNA stability are ...
# doi                                          10.1261/rna.066787.118
# date_published                                             2018 Oct
# PMC                                                      PMC6140462
# journal                                        RNA (New York, N.Y.)
# Name: 54, dtype: object
#
# 31120880
# index: 	 55
# PMID                                                       31120880
# authors            Ajeet K Sharma,  Pietro Sormanni,  Nabeel Ahm...
# abstract          Analysis methods based on simulations and opti...
# title             A chemical kinetic basis for measuring transla...
# doi                                    10.1371/journal.pcbi.1007070
# date_published                                             2019 May
# PMC                                                      PMC6559674
# journal                                  PLoS computational biology
# Name: 55, dtype: object
#
# 30044225
# index: 	 56
# PMID                                                       30044225
# authors                  Jacob W Freimer,  T J Hu,  Robert Blelloch
# abstract          Translation and mRNA degradation are intimatel...
# title             Decoupling the impact of microRNAs on translat...
# doi                                             10.7554/eLife.38014
# date_published                                          2018 Jul 25
# PMC                                                      PMC6086665
# journal                                                       eLife
# Name: 56, dtype: object
#
# 30102689
# index: 	 57
# PMID                                                       30102689
# authors            Fabio Lauria,  Toma Tebaldi,  Paola Bernabo, ...
# abstract          Ribosome profiling is a powerful technique use...
# title             riboWaltz: Optimization of ribosome P-site pos...
# doi                                    10.1371/journal.pcbi.1006169
# date_published                                             2018 Aug
# PMC                                                      PMC6112680
# journal                                  PLoS computational biology
# Name: 57, dtype: object
#
# 30048615
# index: 	 58
# PMID                                                       30048615
# authors            Mareen Engel,  Carola Eggert,  Paul M Kaplick...
# abstract          N(6)-methyladenosine (m(6)A) and N(6),2'-O-dim...
# title             The Role of m(6)A/m-RNA Methylation in Stress ...
# doi                                    10.1016/j.neuron.2018.07.009
# date_published                                          2018 Jul 25
# PMC                                                      PMC6069762
# journal                                                      Neuron
# Name: 58, dtype: object
#
# 30158700
# index: 	 59
# PMID                                                       30158700
# authors            Ayala Shiber,  Kristina Doring,  Ulrike Fried...
# abstract          The folding of newly synthesized proteins to t...
# title             Cotranslational assembly of protein complexes ...
# doi                                       10.1038/s41586-018-0462-y
# date_published                                             2018 Sep
# PMC                                                      PMC6372068
# journal                                                      Nature
# Name: 59, dtype: object
#
# 29925953
# index: 	 62
# PMID                                                       29925953
# authors            Francesca Rapino,  Sylvain Delaunay,  Florian...
# abstract          Reprogramming of mRNA translation has a key ro...
# title             Codon-specific translation reprogramming promo...
# doi                                       10.1038/s41586-018-0243-7
# date_published                                             2018 Jun
# PMC                                                            None
# journal                                                      Nature
# Name: 62, dtype: object
#
# 29570733
# index: 	 63
# PMID                                                       29570733
# authors                              Md Shamimuzzaman,  Lila Vodkin
# abstract          To understand translational capacity on a geno...
# title             Ribosome profiling reveals changes in translat...
# doi                                    10.1371/journal.pone.0194596
# date_published                                                 2018
# PMC                                                      PMC5865733
# journal                                                    PloS one
# Name: 63, dtype: object
#
# 29228904
# index: 	 64
# PMID                                                       29228904
# authors            Musa A Hassan,  Juan J Vasquez,  Chew Guo-Lia...
# abstract          BACKGROUND: The lytic cycle of the protozoan p...
# title             Comparative ribosome profiling uncovers a domi...
# doi                                       10.1186/s12864-017-4362-6
# date_published                                          2017 Dec 11
# PMC                                                      PMC5725899
# journal                                                BMC genomics
# Name: 64, dtype: object
#
# 30485811
# index: 	 66
# PMID                                                       30485811
# authors            Peter H Sudmant,  Hyeseung Lee,  Daniel Domin...
# abstract          Particular brain regions and cell populations ...
# title             Widespread Accumulation of Ribosome-Associated...
# doi                                    10.1016/j.celrep.2018.10.094
# date_published                                          2018 Nov 27
# PMC                                                      PMC6354779
# journal                                                Cell reports
# Name: 66, dtype: object
#
# 28578850
# index: 	 68
# PMID                                                       28578850
# authors            Tzu-Yu Liu,  Hector H Huang,  Diamond Wheeler...
# abstract          Ribosome profiling is a widespread tool for st...
# title             Time-Resolved Proteomics Extends Ribosome Prof...
# doi                                      10.1016/j.cels.2017.05.001
# date_published                                          2017 Jun 28
# PMC                                                      PMC5546878
# journal                                                Cell systems
# Name: 68, dtype: object
#
# 28241004
# index: 	 69
# PMID                                                       28241004
# authors            Hyun Yong Jin,  Hiroyo Oda,  Pengda Chen,  Ch...
# abstract          MicroRNAs (miRNAs) are thought to exert their ...
# title             Differential Sensitivity of Target Genes to Tr...
# doi                                    10.1371/journal.pgen.1006623
# date_published                                             2017 Feb
# PMC                                                      PMC5348049
# journal                                               PLoS genetics
# Name: 69, dtype: object
#
# 28212626
# index: 	 70
# PMID                                                       28212626
# authors                 Ke Zou,  Qi Ouyang,  Hao Li,  Jiashun Zheng
# abstract          BACKGROUND: Among twenty amino acids, methioni...
# title             A global characterization of the translational...
# doi                                       10.1186/s12864-017-3483-2
# date_published                                          2017 Feb 17
# PMC                                                      PMC5316152
# journal                                                BMC genomics
# Name: 70, dtype: object
#
# 29643507
# index: 	 71
# PMID                                                       29643507
# authors            Kifayathullah Liakath-Ali,  Eric W Mills,  In...
# abstract          Ribosome-associated mRNA quality control mecha...
# title             An evolutionarily conserved ribosome-rescue pa...
# doi                                       10.1038/s41586-018-0032-3
# date_published                                             2018 Apr
# PMC                                                            None
# journal                                                      Nature
# Name: 71, dtype: object
#
# 28854918;28977509;34721520
# index: 	 72
# PMID                                                       28854918
# authors            Adam Giess,  Veronique Jonckheere,  Elvis Nda...
# abstract          BACKGROUND: While methods for annotation of ge...
# title             Ribosome signatures aid bacterial translation ...
# doi                                       10.1186/s12915-017-0416-0
# date_published                                          2017 Aug 30
# PMC                                                      PMC5576327
# journal                                                 BMC biology
# Name: 72, dtype: object
#
# 28077873
# index: 	 73
# PMID                                                       28077873
# authors            Ataman Sendoel,  Joshua G Dunn,  Edwin H Rodr...
# abstract          We are just beginning to understand how transl...
# title             Translation from unconventional 5' start sites...
# doi                                             10.1038/nature21036
# date_published                                          2017 Jan 26
# PMC                                                      PMC5287289
# journal                                                      Nature
# Name: 73, dtype: object
#
# 28057705
# index: 	 74
# PMID                                                       28057705
# authors            Heidi M Blank,  Ricardo Perez,  Chong He,  Na...
# abstract          Translational control during cell division det...
# title             Translational control of lipogenic enzymes in ...
# doi                                         10.15252/embj.201695050
# date_published                                          2017 Feb 15
# PMC                                                      PMC5694946
# journal                                            The EMBO journal
# Name: 74, dtype: object
#
# 28003464
# index: 	 75
# PMID                                                       28003464
# authors            Hayami Sugiyama,  Kazutoshi Takahashi,  Takuy...
# abstract          Novel APOBEC1 target 1 (Nat1) (also known as "...
# title             Nat1 promotes translation of specific proteins...
# doi                                         10.1073/pnas.1617234114
# date_published                                          2017 Jan 10
# PMC                                                      PMC5240712
# journal           Proceedings of the National Academy of Science...
# Name: 75, dtype: object
#
# 28091612;31896772
# index: 	 76
# PMID                                                       28091612
# authors            Thomas Beuchert Kallehauge,  Shangzhong Li,  ...
# abstract          Recombinant protein production coopts the host...
# title             Ribosome profiling-guided depletion of an mRNA...
# doi                                               10.1038/srep40388
# date_published                                          2017 Jan 16
# PMC                                                      PMC5238448
# journal                                          Scientific reports
# Name: 76, dtype: object
#
# 27791167
# index: 	 77
# PMID                                                       27791167
# authors            Polly Yingshan Hsu,  Lorenzo Calviello,  Hsin...
# abstract          Deep sequencing of ribosome footprints (riboso...
# title             Super-resolution ribosome profiling reveals un...
# doi                                         10.1073/pnas.1614788113
# date_published                                           2016 Nov 8
# PMC                                                      PMC5111709
# journal           Proceedings of the National Academy of Science...
# Name: 77, dtype: object
#
# 27821408
# index: 	 78
# PMID                                                       27821408
# authors            Jennifer Jungfleisch,  Danny D Nedialkova,  I...
# abstract          The impact of RNA structures in coding sequenc...
# title             A novel translational control mechanism involv...
# doi                                           10.1101/gr.209015.116
# date_published                                             2017 Jan
# PMC                                                      PMC5204348
# journal                                             Genome research
# Name: 78, dtype: object
#
# 27924019
# index: 	 79
# PMID                                                       27924019
# authors                            Jae-Yeon Hwang,  Allen R Buskirk
# abstract          Implicated in persistence and stress response ...
# title             A ribosome profiling study of mRNA cleavage by...
# doi                                              10.1093/nar/gkw944
# date_published                                           2017 Jan 9
# PMC                                                      PMC5224514
# journal                                      Nucleic acids research
# Name: 79, dtype: object
#
# 27681415
# index: 	 80
# PMID                                                       27681415
# authors            Eric W Mills,  Jamie Wangen,  Rachel Green,  ...
# abstract          Protein synthesis continues in platelets and m...
# title             Dynamic Regulation of a Ribosome Rescue Pathwa...
# doi                                    10.1016/j.celrep.2016.08.088
# date_published                                          2016 Sep 27
# PMC                                                      PMC5111367
# journal                                                Cell reports
# Name: 80, dtype: object
#
# 29321322
# index: 	 82
# PMID                                                       29321322
# authors            David W Reid,  Rafael K Campos,  Jessica R Ch...
# abstract          A primary question in dengue virus (DENV) biol...
# title             Dengue Virus Selectively Annexes Endoplasmic R...
# doi                                            10.1128/JVI.01766-17
# date_published                                           2018 Apr 1
# PMC                                                      PMC5972907
# journal                                         Journal of virology
# Name: 82, dtype: object
#
# 27450428
# index: 	 84
# PMID                                                       27450428
# authors            Aaron Lecanda,  Benedikt S Nilges,  Puneet Sh...
# abstract          Protein translation is at the heart of cellula...
# title             Dual randomization of oligonucleotides to redu...
# doi                                     10.1016/j.ymeth.2016.07.011
# date_published                                           2016 Sep 1
# PMC                                                      PMC5024760
# journal                                 Methods (San Diego, Calif.)
# Name: 84, dtype: object
#
# 27306184
# index: 	 86
# PMID                                                       27306184
# authors            Sandra Blanco,  Roberto Bandiera,  Martyna Po...
# abstract          Whether protein synthesis and cellular stress ...
# title             Stem cell function and stress response are con...
# doi                                             10.1038/nature18282
# date_published                                          2016 Jun 16
# PMC                                                      PMC5040503
# journal                                                      Nature
# Name: 86, dtype: object
#
# 27380875
# index: 	 87
# PMID                                                       27380875
# authors            Nicholas Hornstein,  Daniela Torres,  Sohani ...
# abstract          Ribosome profiling has emerged as a powerful t...
# title             Ligation-free ribosome profiling of cell type-...
# doi                                       10.1186/s13059-016-1005-1
# date_published                                           2016 Jul 5
# PMC                                                      PMC4934013
# journal                                              Genome biology
# Name: 87, dtype: object
#
# 27641505
# index: 	 88
# PMID                                                       27641505
# authors            Aditya Radhakrishnan,  Ying-Hsin Chen,  Sophi...
# abstract          A major determinant of mRNA half-life is the c...
# title             The DEAD-Box Protein Dhh1p Couples mRNA Decay ...
# doi                                      10.1016/j.cell.2016.08.053
# date_published                                          2016 Sep 22
# PMC                                                      PMC5635654
# journal                                                        Cell
# Name: 88, dtype: object
#
# 27791168
# index: 	 89
# PMID                                                       27791168
# authors            Jared M Schrader,  Gene-Wei Li,  W Seth Child...
# abstract          Progression of the Caulobacter cell cycle requ...
# title             Dynamic translation regulation in Caulobacter ...
# doi                                         10.1073/pnas.1614795113
# date_published                                           2016 Nov 1
# PMC                                                      PMC5098616
# journal           Proceedings of the National Academy of Science...
# Name: 89, dtype: object
#
# 26776510
# index: 	 90
# PMID                                                       26776510
# authors            Fuad Mohammad,  Christopher J Woolstenhulme, ...
# abstract          The rate of protein synthesis varies according...
# title             Clarifying the Translational Pausing Landscape...
# doi                                    10.1016/j.celrep.2015.12.073
# date_published                                           2016 Feb 2
# PMC                                                      PMC4835026
# journal                                                Cell reports
# Name: 90, dtype: object
#
# 26764022
# index: 	 91
# PMID                                                       26764022
# authors            Alexandra Popa,  Kevin Lebrigand,  Pascal Bar...
# abstract          BACKGROUND: Open reading frames are common in ...
# title             Pateamine A-sensitive ribosome profiling revea...
# doi                                       10.1186/s12864-016-2384-0
# date_published                                          2016 Jan 14
# PMC                                                      PMC4712605
# journal                                                BMC genomics
# Name: 91, dtype: object
#
# 26393539
# index: 	 92
# PMID                                                       26393539
# authors            Marilyn Parsons,  Gowthaman Ramasamy,  Elton ...
# abstract          Since the initial publication of the trypanoso...
# title             Advancing Trypanosoma brucei genome annotation...
# doi                                10.1016/j.molbiopara.2015.09.002
# date_published                                             2015 Aug
# PMC                                                      PMC4644489
# journal                      Molecular and biochemical parasitology
# Name: 92, dtype: object
#
# 26900662;26687005
# index: 	 93
# PMID                                                       26900662
# authors            Zhe Ji,  Ruisheng Song,  Hailiang Huang,  Avi...
# abstract          Ribosome profiling is widely used to study tra...
# title             Transcriptome-scale RNase-footprinting of RNA-...
# doi                                                10.1038/nbt.3441
# date_published                                             2016 Apr
# PMC                                                      PMC4824641
# journal                                        Nature biotechnology
# Name: 93, dtype: object
#
# 26538417
# index: 	 94
# PMID                                                       26538417
# authors            Ran Elkon,  Fabricio Loayza-Puch,  Gozde Kork...
# abstract          c-Myc is one of the major human proto-oncogene...
# title             Myc coordinates transcription and translation ...
# doi                                         10.15252/embr.201540717
# date_published                                             2015 Dec
# PMC                                                      PMC4687422
# journal                                                EMBO reports
# Name: 94, dtype: object
#
# 26486724;27114907;28475894
# index: 	 95
# PMID                                                       26486724
# authors            Peggy Janich,  Alaaddin Bulak Arpat,  Violeta...
# abstract          Mammalian gene expression displays widespread ...
# title             Ribosome profiling reveals the rhythmic liver ...
# doi                                           10.1101/gr.195404.115
# date_published                                             2015 Dec
# PMC                                                      PMC4665006
# journal                                             Genome research
# Name: 95, dtype: object
#
# 27161320
# index: 	 96
# PMID                                                       27161320
# authors            David W Reid,  Angeline S L Tay,  Jeyapriya R...
# abstract          Phosphorylation of eukaryotic initiation facto...
# title                                                          None
# doi                                            10.1128/MCB.00190-16
# date_published    2016 Jul 1TI - Complementary Roles of GADD34- ...
# PMC                                                      PMC4911741
# journal                              Molecular and cellular biology
# Name: 96, dtype: object
#
# 26338483
# index: 	 98
# PMID                                                       26338483
# authors            Christopher Jang,  Nicholas F Lahens,  John B...
# ...
# authors            Valentina Gandin,  Laia Masvidal,  Marie Carg...
# abstract          Ternary complex (TC) and eIF4F complex assembl...
# title             mTORC1 and CK2 coordinate ternary and eIF4F co...
# doi                                             10.1038/ncomms11127
# date_published                                           2016 Apr 4
# PMC                                                      PMC4822005
# journal                                       Nature communications
# Name: 496, dtype: object
#
# 10.1101/gr.193342.115
# index: 	 497
# PMID                                                       26297486
# authors            Can Cenik,  Elif Sarinay Cenik,  Gun W Byeon,...
# abstract          Elucidating the consequences of genetic differ...
# title             Integrative analysis of RNA, translation, and ...
# doi                                           10.1101/gr.193342.115
# date_published                                             2015 Nov
# PMC                                                      PMC4617958
# journal                                             Genome research
# Name: 497, dtype: object
#
# 10.1038/s41586-019-1016-7
# index: 	 498
# PMID                                                       30867593
# authors            Huilin Huang,  Hengyou Weng,  Keren Zhou,  To...
# abstract          DNA and histone modifications have notable eff...
# title             Histone H3 trimethylation at lysine 36 guides ...
# doi                                       10.1038/s41586-019-1016-7
# date_published                                             2019 Mar
# PMC                                                      PMC6438714
# journal                                                      Nature
# Name: 498, dtype: object
#
# 10.1016/j.cell.2014.10.041
# index: 	 499
# PMID                                                       25416947
# authors            Karim Majzoub,  Mohamed Lamine Hafirassou,  C...
# abstract          Fighting viral infections is hampered by the s...
# title             RACK1 controls IRES-mediated translation of vi...
# doi                                      10.1016/j.cell.2014.10.041
# date_published                                          2014 Nov 20
# PMC                                                      PMC4243054
# journal                                                        Cell
# Name: 499, dtype: object
#
# 10.1093/nar/gky1292
# index: 	 500
# PMID                                                       30590705
# authors            Botao Liu,  Gemma Molinaro,  Huan Shu,  Emily...
# abstract          Dysregulated protein synthesis is a major unde...
# title             Optimization of ribosome profiling using low-i...
# doi                                             10.1093/nar/gky1292
# date_published                                          2019 Mar 18
# PMC                                                      PMC6411937
# journal                                      Nucleic acids research
# Name: 500, dtype: object
#
# 10.1038/ncomms6248
# index: 	 501
# PMID                                                       25366541
# authors            Je-Hyun Yoon,  Supriyo De,  Subramanya Srikan...
# abstract          Post-transcriptional gene regulation is robust...
# title             PAR-CLIP analysis uncovers AUF1 impact on targ...
# doi                                              10.1038/ncomms6248
# date_published                                           2014 Nov 4
# PMC                                                      PMC4291169
# journal                                       Nature communications
# Name: 501, dtype: object
#
# 10.7554/eLife.03971
# index: 	 502
# PMID                                                       25621764
# authors            Dmitry E Andreev,  Patrick B F O'Connor,  Cia...
# abstract          Eukaryotic cells rapidly reduce protein synthe...
# title             Translation of 5' leaders is pervasive in gene...
# doi                                             10.7554/eLife.03971
# date_published                                          2015 Jan 26
# PMC                                                      PMC4383229
# journal                                                       eLife
# Name: 502, dtype: object
#
# 10.1016/j.celrep.2013.11.045
# index: 	 503
# PMID                                                       24373965
# authors            Caleb McKinney,  Jiri Zavadil,  Christopher B...
# abstract          Unlike many viruses that suppress cellular pro...
# title             Global reprogramming of the cellular translati...
# doi                                    10.1016/j.celrep.2013.11.045
# date_published                                          2014 Jan 16
# PMC                                                      PMC3975909
# journal                                                Cell reports
# Name: 503, dtype: object
#
# 10.1155/2018/7089174
# index: 	 504
# PMID                                                       31549036
# authors            Ji Wan,  Xiangwei Gao,  Yuanhui Mao,  Xingqia...
# abstract          Upon initiation at a start codon, the ribosome...
# title             A Coding Sequence-Embedded Principle Governs T...
# doi                                            10.1155/2018/7089174
# date_published                                                 2018
# PMC                                                      PMC6750092
# journal                                 Research (Washington, D.C.)
# Name: 504, dtype: object
#
# index: 	 505
# PMID              NaN
# authors           NaN
# abstract          NaN
# title             NaN
# doi               NaN
# date_published    NaN
# PMC               NaN
# journal           NaN
# Name: 505, dtype: object
#
# 10.1093/nar/gkx469
# index: 	 506
# PMID                                                       28541577
# authors            Daria Fijalkowska,  Steven Verbruggen,  Elvis...
# abstract          Alternative translation initiation mechanisms ...
# title             eIF1 modulates the recognition of suboptimal t...
# doi                                              10.1093/nar/gkx469
# date_published                                          2017 Jul 27
# PMC                                                      PMC5570006
# journal                                      Nucleic acids research
# Name: 506, dtype: object
#
# 10.1038/nature16982
# index: 	 507
# PMID                                                       26878238
# authors            Fabricio Loayza-Puch,  Koos Rooijers,  Levi C...
# abstract          Tumour growth and metabolic adaptation may res...
# title             Tumour-specific proline vulnerability uncovere...
# doi                                             10.1038/nature16982
# date_published                                          2016 Feb 25
# PMC                                                            None
# journal                                                      Nature
# Name: 507, dtype: object
#
# index: 	 508
# PMID              NaN
# authors           NaN
# abstract          NaN
# title             NaN
# doi               NaN
# date_published    NaN
# PMC               NaN
# journal           NaN
# Name: 508, dtype: object
#
# 10.1016/j.celrep.2019.10.129
# index: 	 509
# PMID                                                       31801078
# authors            Hema Manjunath,  He Zhang,  Frederick Rehfeld...
# abstract          Sequences within 5' UTRs dictate the site and ...
# title             Suppression of Ribosomal Pausing by eIF5A Is N...
# doi                                    10.1016/j.celrep.2019.10.129
# date_published                                           2019 Dec 3
# PMC                                                      PMC6917043
# journal                                                Cell reports
# Name: 509, dtype: object
#
# 10.15252/embr.201744000
# index: 	 510
# PMID                                                       28274951
# authors            Fabricio Loayza-Puch,  Koos Rooijers,  Jelle ...
# abstract          Cancer cells modulate their metabolic networks...
# title             TGFbeta1-induced leucine limitation uncovered ...
# doi                                         10.15252/embr.201744000
# date_published                                             2017 Apr
# PMC                                                      PMC5376977
# journal                                                EMBO reports
# Name: 510, dtype: object
#
# 10.1038/s41598-020-59678-w
# index: 	 511
# PMID                                                       32066800
# authors            Astrid Haas,  Benedikt S Nilges,  Sebastian A...
# abstract          PDCD4, the protein encoded by the tumor suppre...
# title             PDCD4 controls the G1/S-phase transition in a ...
# doi                                      10.1038/s41598-020-59678-w
# date_published                                          2020 Feb 17
# PMC                                                      PMC7026441
# journal                                          Scientific reports
# Name: 511, dtype: object
#
# 10.1101/gad.340695.120
# index: 	 512
# PMID                                                       32943573
# authors            Lior Lasman,  Vladislav Krupalnik,  Sergey Vi...
# abstract          The N6-methyladenosine (m(6)A) modification is...
# title             Context-dependent functional compensation betw...
# doi                                          10.1101/gad.340695.120
# date_published                                           2020 Oct 1
# PMC                                                      PMC7528697
# journal                                         Genes & development
# Name: 512, dtype: object
#
# 10.1371/journal.pbio.2005903
# index: 	 513
# PMID                                                       30208026
# authors            Yinuo J Wang,  Pavanapuresan P Vaidyanathan, ...
# abstract          Ribosome-binding proteins function broadly in ...
# title             Lso2 is a conserved ribosome-bound protein req...
# doi                                    10.1371/journal.pbio.2005903
# date_published                                             2018 Sep
# PMC                                                      PMC6135351
# journal                                                PLoS biology
# Name: 513, dtype: object
#
# 10.1093/nar/gkx432
# index: 	 514
# PMID                                                       28520920
# authors            Magnus E Jakobsson,  Jedrzej Malecki,  Benedi...
# abstract          Many cellular proteins are methylated on lysin...
# title             Methylation of human eukaryotic elongation fac...
# doi                                              10.1093/nar/gkx432
# date_published                                          2017 Aug 21
# PMC                                                      PMC5737405
# journal                                      Nucleic acids research
# Name: 514, dtype: object
#
# 10.1093/nar/gkab036
# index: 	 515
# PMID                                                       33556964
# authors            Agnes Karasik,  Grant D Jones,  Andrew V DePa...
# abstract          Ribonuclease L (RNase L) is activated as part ...
# title             Activation of the antiviral factor RNase L tri...
# doi                                             10.1093/nar/gkab036
# date_published                                          2021 Jun 21
# PMC                                                      PMC8216459
# journal                                      Nucleic acids research
# Name: 515, dtype: object
#
# 10.1038/ni.3205
# index: 	 516
# PMID                                                       26147685
# authors            Xiaodi Su,  Yingpu Yu,  Yi Zhong,  Eugenia G ...
# abstract          Interferon-gamma (IFN-gamma) primes macrophage...
# title             Interferon-gamma regulates cellular metabolism...
# doi                                                 10.1038/ni.3205
# date_published                                             2015 Aug
# PMC                                                      PMC4509841
# journal                                           Nature immunology
# Name: 516, dtype: object
#
# 10.1186/s12864-019-6277-x
# index: 	 517
# PMID                                                       31783727
# authors            Gemma B Danks,  Heloisa Galbiati,  Martina Ra...
# abstract          BACKGROUND: In phylogenetically diverse organi...
# title             Trans-splicing of mRNAs links gene transcripti...
# doi                                       10.1186/s12864-019-6277-x
# date_published                                          2019 Nov 29
# PMC                                                      PMC6883708
# journal                                                BMC genomics
# Name: 517, dtype: object
#
# 10.1016/j.jare.2020.08.009
# index: 	 518
# PMID                                                       33364047
# authors            F Lerebours,  S Vacher,  J M Guinebretiere,  ...
# abstract          Introduction: Inflammatory Breast Cancer (IBC)...
# title             Hemoglobin overexpression and splice signature...
# doi                                      10.1016/j.jare.2020.08.009
# date_published                                             2021 Feb
# PMC                                                      PMC7753232
# journal                                Journal of advanced research
# Name: 518, dtype: object
#
# index: 	 519
# PMID              NaN
# authors           NaN
# abstract          NaN
# title             NaN
# doi               NaN
# date_published    NaN
# PMC               NaN
# journal           NaN
# Name: 519, dtype: object
#
# 10.1016/j.cell.2015.05.014
# index: 	 520
# PMID                                                       26046440
# authors            Xiao Wang,  Boxuan Simen Zhao,  Ian A Roundtr...
# abstract          N(6)-methyladenosine (m(6)A) is the most abund...
# title             N(6)-methyladenosine Modulates Messenger RNA T...
# doi                                      10.1016/j.cell.2015.05.014
# date_published                                           2015 Jun 4
# PMC                                                      PMC4825696
# journal                                                        Cell
# Name: 520, dtype: object
#
# index: 	 521
# PMID              NaN
# authors           NaN
# abstract          NaN
# title             NaN
# doi               NaN
# date_published    NaN
# PMC               NaN
# journal           NaN
# Name: 521, dtype: object
#
# index: 	 522
# PMID              NaN
# authors           NaN
# abstract          NaN
# title             NaN
# doi               NaN
# date_published    NaN
# PMC               NaN
# journal           NaN
# Name: 522, dtype: object
#
# index: 	 523
# PMID              NaN
# authors           NaN
# abstract          NaN
# title             NaN
# doi               NaN
# date_published    NaN
# PMC               NaN
# journal           NaN
# Name: 523, dtype: object
#
# 10.1038/nature16982
# index: 	 524
# PMID                                                       26878238
# authors            Fabricio Loayza-Puch,  Koos Rooijers,  Levi C...
# abstract          Tumour growth and metabolic adaptation may res...
# title             Tumour-specific proline vulnerability uncovere...
# doi                                             10.1038/nature16982
# date_published                                          2016 Feb 25
# PMC                                                            None
# journal                                                      Nature
# Name: 524, dtype: object
#
# 10.1093/nar/gky873
# index: 	 525
# PMID                                                       30260431
# authors            Rosario Avolio,  Aino I Jarvelin,  Shabaz Moh...
# abstract          Syndesmos (SDOS) is a functionally poorly char...
# title             Protein Syndesmos is a novel RNA-binding prote...
# doi                                              10.1093/nar/gky873
# date_published                                          2018 Dec 14
# PMC                                                      PMC6294507
# journal                                      Nucleic acids research
# Name: 525, dtype: object
#
# index: 	 526
# PMID              NaN
# authors           NaN
# abstract          NaN
# title             NaN
# doi               NaN
# date_published    NaN
# PMC               NaN
# journal           NaN
# Name: 526, dtype: object

# %%
print(paper_info_df.count())


paper_info_df.to_csv("data/ribo_seq_paper_info.csv", index=False)
# Out:
# PMID              448
# authors           448
# abstract          444
# title             444
# doi               448
# date_published    448
# PMC               405
# journal           448
# dtype: int64

# %%
superset = pd.concat([superset, paper_info_df], axis=1)

for col in superset.columns:
    if col in ['PubMed ID', 'doi or pubmed id', 'All references', 'Journal', 'Contact']:
        del superset[col]

# %%
superset.to_csv("data/ribosome_profiling_superset.tsv", sep="\t", index=False)
